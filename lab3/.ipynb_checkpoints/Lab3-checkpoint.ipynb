# %%
# %load_ext tensorboard
# %tensorboard --logdir logs
# Out:
#       <iframe id="tensorboard-frame-8105f41c34e4315a" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-8105f41c34e4315a");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
import datetime, os
import numpy as np
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from tensorflow.keras import optimizers
from tensorflow.keras import preprocessing
from tensorflow.keras import backend as K
from tensorflow.keras.losses import mse
from tensorflow.keras.utils import plot_model

import pandas as pd
from PIL import Image
from keras.utils import load_img
from keras.utils import img_to_array
# I don't think we need this function
# from keras.utils import array_to_img

# %%
training_csv = pd.read_csv('fairface_label_train.csv')
# training_csv = training_csv.iloc[1:200]
# training_csv = training_csv.reset_index()
training_images = []
x = 0
for index, row in training_csv.iterrows():
    oldx = x
    x = float(index)/86745 * 100
    if int(x) > int(oldx) or x == 0:
        print(float(index)/len(training_csv) * 100)
    image = Image.open(row['file']).convert("L") # load_img(row['file'], color_mode="grayscale", target_size=(32,32))
    data = np.asarray(image)
    training_images.append(data)
#     print(f"Loaded image: {type(image)}")
#     print(f"image #{index} file name: {row['file']}")
#     print(f"image #{index} format: {image.format}")
#     print(f"image #{index} size: {image.size}")
    image_array = np.asarray(image) # img_to_array(image) (using the keras methods gives float32 type instead of uint8, not sure which we need)
#     print(f"Numpy array: {type(image_array)}")
#     print(f"image array #{index} type: {image_array.dtype}")
#     print(f"image array #{index} shape: {image_array.shape}")
testing_csv = pd.read_csv('fairface_label_val.csv')
# testing_csv = testing_csv.iloc[1:50]
# testing_csv = testing_csv.reset_index()
testing_images = []
x = 0
for index, row in testing_csv.iterrows():
    oldx = x
    x = float(index)/86745 * 100
    if int(x) > int(oldx) or x == 0:
        print(float(index)/len(testing_csv) * 100)
    image = Image.open(row['file']).convert("L")
    data = np.asarray(image)
    testing_images.append(data)
# Out:
# 0.0
# 1.000645577792124
# 2.000138338098312
# 3.000783915890436
# 4.000276676196624
# 5.000922253988749
# 6.000415014294937
# 7.001060592087061
# 8.000553352393249
# 9.001198930185375
# 10.000691690491562
# 11.00018445079775
# 12.000830028589874
# 13.000322788896062
# 14.000968366688186
# 15.000461126994374
# 16.001106704786498
# 17.000599465092687
# 18.00124504288481
# 19.000737803190997
# 20.000230563497187
# 21.00087614128931
# 22.0003689015955
# 23.001014479387624
# 24.00050723969381
# 25.001152817485934
# 26.000645577792124
# 27.00129115558425
# 28.000783915890437
# 29.00142949368256
# 30.000922253988747
# 31.000415014294937
# 32.00106059208706
# 33.00055335239325
# 34.001198930185375
# 35.00069169049156
# 36.001337268283685
# 37.000830028589874
# 38.001475606381995
# 39.00096836668819
# 40.000461126994374
# 41.0011067047865
# 42.000599465092684
# 43.00124504288481
# 44.000737803191
# 45.00138338098312
# 46.00087614128931
# 47.00152171908144
# 48.00101447938762
# 49.00166005717975
# 50.00115281748594
# 51.00064557779213
# 52.00129115558425
# 53.00078391589044
# 54.001429493682565
# 55.00092225398875
# 56.001567831780875
# 57.00106059208706
# 58.001706169879185
# 59.001198930185375
# 60.00069169049156
# 61.001337268283685
# 62.000830028589874
# 63.001475606381995
# 64.00096836668818
# 65.00161394448031
# 66.0011067047865
# 67.00175228257862
# 68.0012450428848
# 69.00189062067693
# 70.00138338098311
# 71.00087614128931
# 72.00152171908144
# 73.00101447938762
# 74.00166005717975
# 75.00115281748594
# 76.00179839527806
# 77.00129115558425
# 78.00193673337638
# 79.00142949368256
# 80.00092225398875
# 81.00156783178087
# 82.00106059208706
# 83.00170616987918
# 84.00119893018537
# 85.0018445079775
# 86.00133726828368
# 87.0019828460758
# 88.001475606382
# 89.00212118417411
# 90.00161394448031
# 91.0011067047865
# 92.00175228257862
# 93.0012450428848
# 94.00189062067693
# 95.00138338098311
# 96.00202895877524
# 97.00152171908144
# 98.00216729687355
# 99.00166005717975
# 0.0
# 7.924046010589739
# 15.838962935913822
# 23.76300894650356
# 31.677925871827643
# 39.60197188241738
# 47.516888807741466
# 55.4409348183312
# 63.355851743655286
# 71.27989775424503
# 79.1948146795691
# 87.1097316048932
# 95.03377761548293

# %%
# Min-Max Scale the training_images based on their min and max values (per image, not just scaled from 0 to 255)
#                                                at least according to the google chat  ^^^
temp = []
for i in training_images:
    mymaxes = []
    mymins = []
    for j in i:
        mymaxes.append(max(j))
        mymins.append(min(j))
    mymax = max(mymaxes)
    mymin = min(mymins)
    tempcol = []
    for j in i:
        temprow = []
        for k in j:
            temprow.append((k - mymin) / (mymax - mymin))
        tempcol.append(temprow)
    temp.append(tempcol)
training_images = temp
training_images = np.array(training_images)
# Scale the testing_images the same way
temp = []
for i in testing_images:
    mymaxes = []
    mymins = []
    for j in i:
        mymaxes.append(max(j))
        mymins.append(min(j))
    mymax = max(mymaxes)
    mymin = min(mymins)
    tempcol = []
    for j in i:
        temprow = []
        for k in j:
            temprow.append((k - mymin) / (mymax - mymin))
        tempcol.append(temprow)
    temp.append(tempcol)
testing_images = temp
testing_images = np.array(testing_images)

# %%
#also set up other vectors for training/validation
#Gender
genders = training_csv["gender"]
gens = []
for i in range(len(genders)):
    genset = np.zeros(2)
    if "Female" in genders[i]:
        genset[0] = 1
    else:
        genset[1] = 1
    gens.append(genset)
genders = gens.copy()

gendersVal = testing_csv["gender"]
gens = []
for i in range(len(gendersVal)):
    genset = np.zeros(2)
    if "Female" in gendersVal[i]:
        genset[0] = 1
    else:
        genset[1] = 1
    gens.append(genset)
gendersVal = gens.copy()

#Race
racs = []
races = training_csv["race"]
for i in races:
    if i not in racs:
        racs.append(i)
tempRaces = []
for i in range(len(races)):
    racset = np.zeros(len(racs))
    racset[racs.index(races[i])] = 1
    tempRaces.append(racset)
races = tempRaces.copy()

racesVal = testing_csv["race"]
tempRaces = []
for i in range(len(racesVal)):
    racset = np.zeros(len(racs))
    racset[racs.index(racesVal[i])] = 1
    tempRaces.append(racset)
racesVal = tempRaces.copy()
numRaces = len(racs)

genders = np.array(genders)
gendersVal = np.array(gendersVal)
races = np.array(races)
racesVal = np.array(racesVal)

# %% [markdown]
# ## Task 1: Fully Connected Neural Network
# ##### 1. Build a feed forward neural network with the following specs (for 2 separate tasks)
# ###### a. Hidden layer 1: 1024 neurons with tanh activation function in each
# ###### b. Hidden layer 2: 512 neurons with sigmoid activation function in each
# ###### c. Hidden layer 3: 100 neurons with reLu
# ###### d. Output layer: n (depending on the task) representing n classes, using softmax activation

# %%
# fmodel = Sequential()
# fmodel.add(keras.Input(shape=(32,32,1)))
# fmodel.add(layers.Dense(1024, activation='tanh'))
# fmodel.add(layers.Dense(512, activation='sigmoid'))
# fmodel.add(layers.Dense(100, activation='relu'))
# # find n for the task, add this layer
# fmodel.add(layers.Dense(n, activation='softmax'))

# %% [markdown]
# ### Task 1, Classification Task A: Gender

# %%
# classify gender
famodel = Sequential()
famodel.add(keras.Input(shape=(32,32,1)))
famodel.add(layers.Flatten())
famodel.add(layers.Dense(1024, activation='tanh'))
famodel.add(layers.Dense(512, activation='sigmoid'))
famodel.add(layers.Dense(100, activation='relu'))
n = 2
famodel.add(layers.Dense(n, activation='softmax'))
# min max already taken care of, use mini-batch gradient descent to optimize categorical cross entropy, 
# record and graph each epoch's epoch-accuracy and epoch-loss for both the training and validation set
# also graph the confusion matrix
opt = keras.optimizers.SGD(learning_rate=0.05)
famodel.compile(
    optimizer=opt,
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S_Task1Genders"))
tensorboard_callback = keras.callbacks.TensorBoard(logdir, histogram_freq=1)

famodel.fit(training_images, genders, epochs=50, batch_size=int(len(training_images)/20), validation_data=(testing_images, gendersVal), callbacks=[tensorboard_callback])
# Out:
# Epoch 1/50
# 21/21 [==============================] - 5s 205ms/step - loss: 0.7512 - accuracy: 0.5260 - val_loss: 0.6868 - val_accuracy: 0.5769
# Epoch 2/50
# 21/21 [==============================] - 4s 203ms/step - loss: 0.6814 - accuracy: 0.5766 - val_loss: 0.6853 - val_accuracy: 0.5259
# Epoch 3/50
# 21/21 [==============================] - 4s 200ms/step - loss: 0.6742 - accuracy: 0.5927 - val_loss: 0.7238 - val_accuracy: 0.4772
# Epoch 4/50
# 21/21 [==============================] - 5s 216ms/step - loss: 0.6724 - accuracy: 0.5925 - val_loss: 0.9349 - val_accuracy: 0.4712
# Epoch 5/50
# 21/21 [==============================] - 5s 221ms/step - loss: 0.6806 - accuracy: 0.5984 - val_loss: 0.8992 - val_accuracy: 0.5288
# Epoch 6/50
# 21/21 [==============================] - 4s 193ms/step - loss: 0.6775 - accuracy: 0.6065 - val_loss: 0.6611 - val_accuracy: 0.6127
# Epoch 7/50
# 21/21 [==============================] - 5s 218ms/step - loss: 0.6613 - accuracy: 0.6100 - val_loss: 0.6706 - val_accuracy: 0.5949
# Epoch 8/50
# 21/21 [==============================] - 4s 185ms/step - loss: 0.6589 - accuracy: 0.6126 - val_loss: 0.7006 - val_accuracy: 0.5217
# Epoch 9/50
# 21/21 [==============================] - 4s 181ms/step - loss: 0.6605 - accuracy: 0.6085 - val_loss: 0.9229 - val_accuracy: 0.4713
# Epoch 10/50
# 21/21 [==============================] - 4s 193ms/step - loss: 0.6701 - accuracy: 0.6083 - val_loss: 0.9145 - val_accuracy: 0.4721
# Epoch 11/50
# 21/21 [==============================] - 4s 193ms/step - loss: 0.6678 - accuracy: 0.6095 - val_loss: 0.7878 - val_accuracy: 0.5301
# Epoch 12/50
# 21/21 [==============================] - 4s 202ms/step - loss: 0.6610 - accuracy: 0.6117 - val_loss: 0.9248 - val_accuracy: 0.5288
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = ['Female', 'Male'])
cm_display.plot()
plt.show()
# Out:
# 343/343 [==============================] - 2s 7ms/step

# %% [markdown]
# ### Task 1, Classification Task B: Race

# %%
# classify race
fbmodel = Sequential()
fbmodel.add(keras.Input(shape=(32,32,1)))
fbmodel.add(layers.Flatten())
fbmodel.add(layers.Dense(1024, activation='tanh'))
fbmodel.add(layers.Dense(512, activation='sigmoid'))
fbmodel.add(layers.Dense(100, activation='relu'))
# find n for the task, add this layer
n = numRaces
fbmodel.add(layers.Dense(n, activation='softmax'))
# min max already taken care of, use mini-batch gradient descent to optimize categorical cross entropy, 
# record and graph each epoch's epoch-accuracy and epoch-loss for both the training and validation set
# also graph the confusion matrix
opt = keras.optimizers.SGD(learning_rate=0.05)
fbmodel.compile(
    optimizer=opt,
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S_Task1Races"))
tensorboard_callback = keras.callbacks.TensorBoard(logdir, histogram_freq=1)

fbmodel.fit(training_images, races, epochs=50, batch_size=int(len(training_images)/20), validation_data=(testing_images, racesVal), callbacks=[tensorboard_callback])
# if you have the setup and training in different blocks in the notebook, 
# you can accidentally train it multiple times, compounding how well it gets trained, 
# so keep the training in the same block as the setup
# Out:
# Epoch 1/50
# 21/21 [==============================] - 5s 216ms/step - loss: 1.9274 - accuracy: 0.1905 - val_loss: 2.1701 - val_accuracy: 0.1121
# Epoch 2/50
# 21/21 [==============================] - 5s 251ms/step - loss: 1.9256 - accuracy: 0.2049 - val_loss: 2.1352 - val_accuracy: 0.1422
# Epoch 3/50
# 21/21 [==============================] - 6s 291ms/step - loss: 1.9186 - accuracy: 0.2216 - val_loss: 2.3485 - val_accuracy: 0.1420
# Epoch 4/50
# 21/21 [==============================] - 5s 253ms/step - loss: 1.9233 - accuracy: 0.2291 - val_loss: 2.0596 - val_accuracy: 0.1915
# Epoch 5/50
# 21/21 [==============================] - 6s 271ms/step - loss: 1.9088 - accuracy: 0.2200 - val_loss: 2.2730 - val_accuracy: 0.1903
# Epoch 6/50
# 21/21 [==============================] - 6s 269ms/step - loss: 1.9231 - accuracy: 0.2236 - val_loss: 1.9988 - val_accuracy: 0.1589
# Epoch 7/50
# 21/21 [==============================] - 6s 272ms/step - loss: 1.8949 - accuracy: 0.2434 - val_loss: 2.0175 - val_accuracy: 0.1425
# Epoch 8/50
# 21/21 [==============================] - 5s 261ms/step - loss: 1.8876 - accuracy: 0.2464 - val_loss: 2.0427 - val_accuracy: 0.1431
# Epoch 9/50
# 21/21 [==============================] - 5s 255ms/step - loss: 1.8849 - accuracy: 0.2506 - val_loss: 2.6690 - val_accuracy: 0.1903
# Epoch 10/50
# 21/21 [==============================] - 5s 231ms/step - loss: 1.9205 - accuracy: 0.2401 - val_loss: 1.9233 - val_accuracy: 0.1755
# Epoch 11/50
# 21/21 [==============================] - 5s 251ms/step - loss: 1.8811 - accuracy: 0.2385 - val_loss: 1.9607 - val_accuracy: 0.1850
# Epoch 12/50
# 21/21 [==============================] - 5s 246ms/step - loss: 1.8762 - accuracy: 0.2471 - val_loss: 1.9653 - val_accuracy: 0.1959
# 21/21 [==============================] - 5s 229ms/step - loss: 1.9372 - accuracy: 0.2607 - val_loss: 2.0196 - val_accuracy: 0.1521
# Epoch 33/50
# 21/21 [==============================] - 5s 225ms/step - loss: 1.8366 - accuracy: 0.2753 - val_loss: 1.9376 - val_accuracy: 0.2185
# Epoch 34/50
# 21/21 [==============================] - 5s 228ms/step - loss: 1.8276 - accuracy: 0.2774 - val_loss: 2.8059 - val_accuracy: 0.1420
# Epoch 35/50
# 21/21 [==============================] - 5s 223ms/step - loss: 1.8758 - accuracy: 0.2754 - val_loss: 1.9699 - val_accuracy: 0.1937
# Epoch 36/50
# 21/21 [==============================] - 5s 224ms/step - loss: 1.8222 - accuracy: 0.2784 - val_loss: 1.8428 - val_accuracy: 0.2866
# Epoch 37/50
# 21/21 [==============================] - 5s 221ms/step - loss: 1.8095 - accuracy: 0.2883 - val_loss: 1.9167 - val_accuracy: 0.2334
# Epoch 38/50
# 21/21 [==============================] - 5s 227ms/step - loss: 1.8085 - accuracy: 0.2888 - val_loss: 2.1632 - val_accuracy: 0.2137
# Epoch 39/50
# 21/21 [==============================] - 5s 227ms/step - loss: 1.8202 - accuracy: 0.2886 - val_loss: 1.8764 - val_accuracy: 0.2247
# Epoch 40/50
# 21/21 [==============================] - 5s 230ms/step - loss: 1.8055 - accuracy: 0.2847 - val_loss: 2.1227 - val_accuracy: 0.2244
# Epoch 41/50
# 21/21 [==============================] - 5s 259ms/step - loss: 1.8150 - accuracy: 0.2916 - val_loss: 2.2102 - val_accuracy: 0.1799
# Epoch 42/50
# 21/21 [==============================] - 5s 254ms/step - loss: 1.8254 - accuracy: 0.2873 - val_loss: 2.2424 - val_accuracy: 0.1717
# Epoch 43/50
# 21/21 [==============================] - 5s 226ms/step - loss: 1.8239 - accuracy: 0.2854 - val_loss: 2.9107 - val_accuracy: 0.1422
# Epoch 44/50
# 21/21 [==============================] - 5s 229ms/step - loss: 1.8514 - accuracy: 0.2919 - val_loss: 2.0746 - val_accuracy: 0.1898
# Epoch 45/50
# 21/21 [==============================] - 5s 232ms/step - loss: 1.8097 - accuracy: 0.2881 - val_loss: 2.1397 - val_accuracy: 0.1647
# Epoch 46/50
# 21/21 [==============================] - 5s 228ms/step - loss: 1.8124 - accuracy: 0.2917 - val_loss: 2.4146 - val_accuracy: 0.1462
# Epoch 47/50
# 21/21 [==============================] - 5s 225ms/step - loss: 1.8264 - accuracy: 0.2892 - val_loss: 1.9203 - val_accuracy: 0.2480
# Epoch 48/50
# 21/21 [==============================] - 5s 231ms/step - loss: 1.7935 - accuracy: 0.2980 - val_loss: 1.8728 - val_accuracy: 0.2037
# Epoch 49/50
# 21/21 [==============================] - 5s 227ms/step - loss: 1.7858 - accuracy: 0.3006 - val_loss: 2.1467 - val_accuracy: 0.1796
# Epoch 50/50
# 21/21 [==============================] - 5s 232ms/step - loss: 1.8164 - accuracy: 0.2941 - val_loss: 2.2882 - val_accuracy: 0.1886

# %%
racesVal = testing_csv["race"]
tempRaces = []
for i in range(len(racesVal)):
    racset = np.zeros(len(racs))
    racset[racs.index(racesVal[i])] = 1
    tempRaces.append(racset)
racesVal = tempRaces.copy()
racesVal = np.array(racesVal)

# %%
plt.rcParams['figure.figsize'] = [10, 10]
x = fbmodel.predict(testing_images)
print(len(x), len(racesVal))
confusion_matrix = metrics.confusion_matrix(racesVal.argmax(axis=1), x.argmax(axis=1))
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = racs)
cm_display.plot()
plt.show()
# Out:
# 343/343 [==============================] - 2s 7ms/step
# 10954 10954

# %% [markdown]
# ## Task 2: Convolutional Network
# #### 2. Build a convolutional network (also for 2 tasks)
# ###### a. conv layer with 40 feature detectors, kernel size 5x5, reLu activation, stride=1, no padding
# ###### b. max pooling layer size 2x2
# ###### c. fully connected layer, 100 neurons reLu activation
# ###### d. output layer: n neurons (depending on task), using softmax activation

# %%
# cmodel = Sequential()
# cmodel.add(layers.Conv2D(filters=40, kernel_size=(5,5), activation='relu', input_shape=(32,32,1), strides=1, padding='valid'))
# cmodel.add(layers.MaxPooling2D(pool_size=2, strides=2, padding='valid'))
# cmodel.add(layers.Dense(100, activation='relu'))
# #find n for the task
# cmodel.add(layers.Dense(n, activation='softmax'))

# %% [markdown]
# ### Task 2, Classification Task A: Gender

# %%
# classify gender
camodel = Sequential()
camodel.add(layers.Conv2D(filters=40, kernel_size=(5,5), activation='relu', input_shape=(32,32,1), strides=1, padding='valid'))
camodel.add(layers.MaxPooling2D(pool_size=2, strides=2, padding='valid'))
camodel.add(layers.Flatten())
camodel.add(layers.Dense(100, activation='relu'))
n = 2
camodel.add(layers.Dense(n, activation='softmax'))

opt = keras.optimizers.SGD(learning_rate=0.05)
camodel.compile(
    optimizer=opt,
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S_Task2Genders"))
tensorboard_callback = keras.callbacks.TensorBoard(logdir, histogram_freq=1)

camodel.fit(training_images, genders, epochs=50, batch_size=int(len(training_images)/20), validation_data=(testing_images, gendersVal), callbacks=[tensorboard_callback])
# Out:
# Epoch 1/50
# 21/21 [==============================] - 34s 2s/step - loss: 0.6791 - accuracy: 0.5803 - val_loss: 0.7089 - val_accuracy: 0.5389
# Epoch 2/50
# 21/21 [==============================] - 31s 1s/step - loss: 0.6706 - accuracy: 0.5923 - val_loss: 1.4641 - val_accuracy: 0.5288
# Epoch 3/50
# 21/21 [==============================] - 29s 1s/step - loss: 0.7213 - accuracy: 0.5613 - val_loss: 0.6801 - val_accuracy: 0.5918
# Epoch 4/50
# 21/21 [==============================] - 28s 1s/step - loss: 0.6719 - accuracy: 0.6073 - val_loss: 0.7313 - val_accuracy: 0.5302
# Epoch 5/50
# 21/21 [==============================] - 29s 1s/step - loss: 0.6668 - accuracy: 0.6057 - val_loss: 0.7354 - val_accuracy: 0.5353
# Epoch 6/50
# 21/21 [==============================] - 28s 1s/step - loss: 0.6625 - accuracy: 0.6080 - val_loss: 0.6899 - val_accuracy: 0.5642
# Epoch 7/50
# 21/21 [==============================] - 28s 1s/step - loss: 0.6574 - accuracy: 0.6125 - val_loss: 1.0304 - val_accuracy: 0.4721
# Epoch 8/50
# 21/21 [==============================] - 29s 1s/step - loss: 0.6929 - accuracy: 0.5851 - val_loss: 0.7183 - val_accuracy: 0.5288
# Epoch 9/50
# 21/21 [==============================] - 29s 1s/step - loss: 0.6714 - accuracy: 0.5904 - val_loss: 0.6677 - val_accuracy: 0.5792
# Epoch 10/50
# 21/21 [==============================] - 30s 1s/step - loss: 0.6547 - accuracy: 0.6120 - val_loss: 0.6695 - val_accuracy: 0.5776
# Epoch 11/50
# 21/21 [==============================] - 29s 1s/step - loss: 0.6526 - accuracy: 0.6158 - val_loss: 0.6501 - val_accuracy: 0.6244
# Epoch 12/50
# 21/21 [==============================] - 28s 1s/step - loss: 0
50
# 21/21 [==============================] - 28s 1s/step - loss: 0.5643 - accuracy: 0.6998 - val_loss: 0.6063 - val_accuracy: 0.6625
# Epoch 42/50
# 21/21 [==============================] - 28s 1s/step - loss: 0.5610 - accuracy: 0.7026 - val_loss: 0.6303 - val_accuracy: 0.6511
# Epoch 43/50
# 21/21 [==============================] - 28s 1s/step - loss: 0.5613 - accuracy: 0.7030 - val_loss: 0.6147 - val_accuracy: 0.6641
# Epoch 44/50
# 21/21 [==============================] - 28s 1s/step - loss: 0.5581 - accuracy: 0.7065 - val_loss: 0.6717 - val_accuracy: 0.5945
# Epoch 45/50
# 21/21 [==============================] - 29s 1s/step - loss: 0.5613 - accuracy: 0.7040 - val_loss: 0.7005 - val_accuracy: 0.5974
# Epoch 46/50
# 21/21 [==============================] - 28s 1s/step - loss: 0.5613 - accuracy: 0.7041 - val_loss: 0.6304 - val_accuracy: 0.6472
# Epoch 47/50
# 21/21 [==============================] - 28s 1s/step - loss: 0.5555 - accuracy: 0.7094 - val_loss: 0.6073 - val_accuracy: 0.6548
# Epoch 48/50
# 21/21 [==============================] - 28s 1s/step - loss: 0.5515 - accuracy: 0.7125 - val_loss: 0.5922 - val_accuracy: 0.6782
# Epoch 49/50
# 21/21 [==============================] - 28s 1s/step - loss: 0.5488 - accuracy: 0.7146 - val_loss: 0.6058 - val_accuracy: 0.6537
# Epoch 50/50
# 21/21 [==============================] - 32s 2s/step - loss: 0.5481 - accuracy: 0.7153 - val_loss: 0.5872 - val_accuracy: 0.6872

# %%
plt.rcParams['figure.figsize'] = [10,10]
x = camodel.predict(testing_images)
confusion_matrix = metrics.confusion_matrix(gendersVal.argmax(axis=1), x.argmax(axis=1))
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = ['Female', 'Male'])
cm_display.plot()
plt.show()
# Out:
# 343/343 [==============================] - 3s 8ms/step

# %% [markdown]
# ### Task 2, Classification Task B: Race

# %%
# classify race
cbmodel = Sequential()
cbmodel.add(layers.Conv2D(filters=40, kernel_size=(5,5), activation='relu', input_shape=(32,32,1), strides=1, padding='valid'))
cbmodel.add(layers.MaxPooling2D(pool_size=2, strides=2, padding='valid'))
cbmodel.add(layers.Flatten())
cbmodel.add(layers.Dense(100, activation='relu'))
n = numRaces
cbmodel.add(layers.Dense(n, activation='softmax'))

opt = keras.optimizers.SGD(learning_rate=0.05)
cbmodel.compile(
    optimizer=opt,
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S_Task2Races"))
tensorboard_callback = keras.callbacks.TensorBoard(logdir, histogram_freq=1)

cbmodel.fit(training_images, races, epochs=50, batch_size=int(len(training_images)/20), validation_data=(testing_images, racesVal), callbacks=[tensorboard_callback])
# Out:
# Epoch 1/50
# 21/21 [==============================] - 32s 1s/step - loss: 1.9220 - accuracy: 0.1882 - val_loss: 2.0251 - val_accuracy: 0.1384
# Epoch 2/50
# 21/21 [==============================] - 32s 2s/step - loss: 1.9212 - accuracy: 0.1875 - val_loss: 1.9645 - val_accuracy: 0.1887
# Epoch 3/50
# 21/21 [==============================] - 34s 2s/step - loss: 1.9078 - accuracy: 0.2002 - val_loss: 1.9531 - val_accuracy: 0.1938
# Epoch 4/50
# 21/21 [==============================] - 29s 1s/step - loss: 1.8981 - accuracy: 0.2246 - val_loss: 1.9454 - val_accuracy: 0.2407
# Epoch 5/50
# 21/21 [==============================] - 30s 1s/step - loss: 1.8883 - accuracy: 0.2387 - val_loss: 2.1091 - val_accuracy: 0.1971
# Epoch 6/50
# 21/21 [==============================] - 30s 1s/step - loss: 1.8913 - accuracy: 0.2320 - val_loss: 1.9422 - val_accuracy: 0.2279
# 21/21 [==============================] - 32s 2s/step - loss: 1.6690 - accuracy: 0.3573 - val_loss: 2.0751 - val_accuracy: 0.1969
# Epoch 47/50
# 21/21 [==============================] - 33s 2s/step - loss: 1.6726 - accuracy: 0.3566 - val_loss: 2.2343 - val_accuracy: 0.2356
# Epoch 48/50
# 21/21 [==============================] - 32s 1s/step - loss: 1.6793 - accuracy: 0.3574 - val_loss: 1.7723 - val_accuracy: 0.3035
# Epoch 49/50
# 21/21 [==============================] - 32s 2s/step - loss: 1.6511 - accuracy: 0.3631 - val_loss: 1.7333 - val_accuracy: 0.3213
# Epoch 50/50
# 21/21 [==============================] - 34s 2s/step - loss: 1.6376 - accuracy: 0.3695 - val_loss: 1.9426 - val_accuracy: 0.2917

# %%
plt.rcParams['figure.figsize'] = [10, 10]
x = cbmodel.predict(testing_images)
confusion_matrix = metrics.confusion_matrix(racesVal.argmax(axis=1), x.argmax(axis=1))
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = racs)
cm_display.plot()
plt.show()
# Out:
# 343/343 [==============================] - 3s 8ms/step

# %% [markdown]
# ## Task 3: Our own Convolutional Network
# ### Can we build our own network architecture to do better than either cmodel?

# %% [markdown]
# ### Task 3, Classification Task A: Gender

# %%
# classify gender
task3amodel = Sequential()
task3amodel.add(layers.Conv2D(filters=50, kernel_size=(7,7), activation='relu', input_shape=(32,32,1), strides=1, padding='same'))
task3amodel.add(layers.MaxPooling2D(pool_size=2, strides=2, padding='valid'))
task3amodel.add(layers.Conv2D(filters=100, kernel_size=(3,3), activation='relu', strides=1, padding='valid'))
task3amodel.add(layers.Flatten())
task3amodel.add(layers.Dense(256, activation='relu'))
#task3amodel.add(layers.Dense(128, activation='relu'))
task3amodel.add(layers.Dense(64, activation='relu'))

n = 2
task3amodel.add(layers.Dense(n, activation='softmax'))

opt = keras.optimizers.SGD(learning_rate=0.05)
task3amodel.compile(
    optimizer=opt,
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S_Task3Genders"))
tensorboard_callback = keras.callbacks.TensorBoard(logdir, histogram_freq=1)

task3amodel.fit(training_images, genders, epochs=50, batch_size=int(len(training_images)/20), validation_data=(testing_images, gendersVal), callbacks=[tensorboard_callback])
# Out:
# Epoch 1/50
# 21/21 [==============================] - 102s 5s/step - loss: 0.6832 - accuracy: 0.5871 - val_loss: 0.7073 - val_accuracy: 0.4862
# Epoch 2/50
# 21/21 [==============================] - 102s 5s/step - loss: 0.6735 - accuracy: 0.5862 - val_loss: 0.8298 - val_accuracy: 0.5288
# Epoch 3/50
# 21/21 [==============================] - 101s 5s/step - loss: 0.6739 - accuracy: 0.6024 - val_loss: 0.6700 - val_accuracy: 0.5943
# Epoch 4/50
# 21/21 [==============================] - 100s 5s/step - loss: 0.6615 - accuracy: 0.6057 - val_loss: 0.7351 - val_accuracy: 0.5248
# Epoch 5/50
# 21/21 [==============================] - 100s 5s/step - loss: 0.6626 - accuracy: 0.6064 - val_loss: 0.7349 - val_accuracy: 0.4819
# Epoch 6/50
# 21/21 [==============================] - 107s 5s/step - loss: 0.6659 - accuracy: 0.6121 - val_loss: 0.7276 - val_accuracy: 0.5374
# Epoch 7/50
# 21/21 [==============================] - 113s 5s/step - loss: 0.5446 - accuracy: 0.7171 - val_loss: 0.5575 - val_accuracy: 0.7060
# Epoch 48/50
# 21/21 [==============================] - 103s 5s/step - loss: 0.5359 - accuracy: 0.7227 - val_loss: 0.6590 - val_accuracy: 0.6234
# Epoch 49/50
# 21/21 [==============================] - 103s 5s/step - loss: 0.5844 - accuracy: 0.7017 - val_loss: 0.6614 - val_accuracy: 0.6206
# Epoch 50/50
# 21/21 [==============================] - 106s 5s/step - loss: 0.5377 - accuracy: 0.7195 - val_loss: 0.8268 - val_accuracy: 0.5773

# %%
plt.rcParams['figure.figsize'] = [10,10]
x = task3amodel.predict(testing_images)
confusion_matrix = metrics.confusion_matrix(gendersVal.argmax(axis=1), x.argmax(axis=1))
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = ['Female', 'Male'])
cm_display.plot()
plt.show()
# Out:
# 343/343 [==============================] - 7s 21ms/step

# %% [markdown]
# ### Task 3, Classification Task B: Race

# %%
# classify race
task3bmodel = Sequential()
task3bmodel.add(layers.Conv2D(filters=50, kernel_size=(7,7), activation='relu', input_shape=(32,32,1), strides=1, padding='same'))
task3bmodel.add(layers.MaxPooling2D(pool_size=2, strides=2, padding='valid'))
task3bmodel.add(layers.Conv2D(filters=50, kernel_size=(3,3), activation='relu', strides=1, padding='valid'))
task3bmodel.add(layers.Flatten())
task3bmodel.add(layers.Dense(120, activation='relu'))

n = numRaces
task3bmodel.add(layers.Dense(n, activation='softmax'))

opt = keras.optimizers.SGD(learning_rate=0.05)
task3bmodel.compile(
    optimizer=opt,
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S_Task3Races"))
tensorboard_callback = keras.callbacks.TensorBoard(logdir, histogram_freq=1)

task3bmodel.fit(training_images, races, epochs=50, batch_size=int(len(training_images)/20), validation_data=(testing_images, racesVal), callbacks=[tensorboard_callback])
# Out:
# Epoch 1/50
# 21/21 [==============================] - 84s 4s/step - loss: 1.9246 - accuracy: 0.1875 - val_loss: 1.9939 - val_accuracy: 0.1384
# Epoch 2/50
# 21/21 [==============================] - 82s 4s/step - loss: 1.9201 - accuracy: 0.1859 - val_loss: 1.9871 - val_accuracy: 0.1425
# Epoch 3/50
# 21/21 [==============================] - 84s 4s/step - loss: 1.9290 - accuracy: 0.1851 - val_loss: 1.9654 - val_accuracy: 0.1292
# Epoch 4/50
# 21/21 [==============================] - 84s 4s/step - loss: 1.9175 - accuracy: 0.1876 - val_loss: 1.9515 - val_accuracy: 0.1783
# Epoch 5/50
# 21/21 [==============================] - 82s 4s/step - loss: 1.9037 - accuracy: 0.2092 - val_loss: 1.9753 - val_accuracy: 0.1803
# Epoch 6/50
# 21/21 [==============================] - 85s 4s/step - loss: 1.8928 - accuracy: 0.2287 - val_loss: 1.9643 - val_accuracy: 0.2041
# Epoch 7/50
# 21/21 [==============================] - 85s 4s/step - loss: 1.8825 - accuracy: 0.2443 - val_loss: 2.4707 - val_accuracy: 0.1925
# Epoch 8/50
# 21/21 [==============================] - 82s 4s/step - loss: 1.9496 - accuracy: 0.2032 - val_loss: 2.2559 - val_accuracy: 0.1420
# Epoch 9/50
# Epoch 49/50
# 21/21 [==============================] - 82s 4s/step - loss: 1.6807 - accuracy: 0.3460 - val_loss: 2.3115 - val_accuracy: 0.1661
# Epoch 50/50
# 21/21 [==============================] - 82s 4s/step - loss: 1.7094 - accuracy: 0.3413 - val_loss: 1.9881 - val_accuracy: 0.2656

# %%
plt.rcParams['figure.figsize'] = [10, 10]
x = task3bmodel.predict(testing_images)
confusion_matrix = metrics.confusion_matrix(racesVal.argmax(axis=1), x.argmax(axis=1))
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = racs)
cm_display.plot()
plt.show()
# Out:
# 343/343 [==============================] - 5s 14ms/step

# %% [markdown]
# ## Task 4: Our own Convolutional Network to do both classifications simultaneously
# ### We can't use Sequential() for this one

# %%
# classify race
task4inputs = keras.Input(shape=(32,32,1))
task4mainbranch = layers.Conv2D(filters=50, kernel_size=(7,7), activation='relu', strides=1, padding='same')(task4inputs)
task4mainbranch = layers.MaxPooling2D(pool_size=2, strides=2, padding='valid')(task4mainbranch)
task4mainbranch = layers.Conv2D(filters=100, kernel_size=(3,3), activation='relu', strides=1, padding='valid')(task4mainbranch)
task4mainbranch = layers.Flatten()(task4mainbranch)
task4gender = layers.Dense(100, activation='relu')(task4mainbranch)
task4gender = layers.Dense(2, activation='softmax', name="gender")(task4gender)
task4race = layers.Dense(100, activation='relu')(task4mainbranch)
task4race = layers.Dense(numRaces, activation='softmax', name="race")(task4race)
task4model = keras.Model(inputs=task4inputs, outputs=[task4gender,task4race], name="task4_model")
print(task4model.summary())

opt = keras.optimizers.SGD(learning_rate=0.05)
task4model.compile(
    optimizer=opt,
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S_Task4"))
tensorboard_callback = keras.callbacks.TensorBoard(logdir, histogram_freq=1)

task4model.fit(training_images, {"gender":genders,"race":races}, epochs=50, batch_size=int(len(training_images)/20), validation_data=(testing_images, {"gender":gendersVal,"race":racesVal}), callbacks=[tensorboard_callback])
# Out:
# Model: "task4_model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_8 (InputLayer)           [(None, 32, 32, 1)]  0           []
#
#  conv2d_12 (Conv2D)             (None, 32, 32, 50)   2500        ['input_8[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 16, 16, 50)  0           ['conv2d_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 14, 14, 100)  45100       ['max_pooling2d_7[0][0]']
#
#  flatten_14 (Flatten)           (None, 19600)        0           ['conv2d_13[0][0]']
#
#  dense_46 (Dense)               (None, 100)          1960100     ['flatten_14[0][0]']
#
#  dense_47 (Dense)               (None, 100)          1960100     ['flatten_14[0][0]']
#
#  gender (Dense)                 (None, 2)            202         ['dense_46[0][0]']
#
#  race (Dense)                   (None, 7)            707         ['dense_47[0][0]']
#
# ==================================================================================================
# Total params: 3,968,709
# Trainable params: 3,968,709
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Epoch 1/50
# 21/21 [==============================] - 118s 5s/step - loss: 2.6073 - gender_loss: 0.6793 - race_loss: 1.9280 - gender_accuracy: 0.5830 - race_accuracy: 0.1813 - val_loss: 3.2080 - val_gender_loss: 1.1389 - val_race_loss: 2.0691 - val_gender_accuracy: 0.5288 - val_race_accuracy: 0.1415
# Epoch 2/50
# 21/21 [==============================] - 107s 5s/step - loss: 2.6468 - gender_loss: 0.7089 - race_loss: 1.9379 - gender_accuracy: 0.5755 - race_accuracy: 0.1843 - val_loss: 2.6389 - val_gender_loss: 0.6984 - val_race_loss: 1.9405 - val_gender_accuracy: 0.5288 - val_race_accuracy: 0.1903
# Epoch 49/50
# 21/21 [==============================] - 103s 5s/step - loss: 2.4054 - gender_loss: 0.6289 - race_loss: 1.7765 - gender_accuracy: 0.6602 - race_accuracy: 0.3225 - val_loss: 2.8818 - val_gender_loss: 0.9720 - val_race_loss: 1.9099 - val_gender_accuracy: 0.4745 - val_race_accuracy: 0.2218
# Epoch 50/50
# 21/21 [==============================] - 103s 5s/step - loss: 2.3193 - gender_loss: 0.6110 - race_loss: 1.7083 - gender_accuracy: 0.6736 - race_accuracy: 0.3367 - val_loss: 3.1455 - val_gender_loss: 0.6015 - val_race_loss: 2.5440 - val_gender_accuracy: 0.6765 - val_race_accuracy: 0.2095

# %%
plt.rcParams['figure.figsize'] = [10, 10]
x,y = task4model.predict(testing_images)
confusion_matrix = metrics.confusion_matrix(gendersVal.argmax(axis=1), x.argmax(axis=1))
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = ["Female", "Male"])
cm_display.plot()
plt.show()
# Out:
# 343/343 [==============================] - 6s 17ms/step

# %%
plt.rcParams['figure.figsize'] = [10, 10]
confusion_matrix = metrics.confusion_matrix(racesVal.argmax(axis=1), y.argmax(axis=1))
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = racs)
cm_display.plot()
plt.show()

# %% [markdown]
# ## Task 5: Variational Auto-Encoder
# ### Use these specs (with some flexibility
# ###### a. at least 2 convolutional layers and 2 deconvolution layers
# ###### b. latent dimension should be at least 5
# ###### c. loss should be either MSE or binary cross entropy

# %%
latent_dim = 8
intermediate_dim = 512
original_dim = 32 * 32
batch_size = 120
def sampling(args):
    """Reparameterization trick by sampling from an isotropic unit Gaussian.

    # Arguments
        args (tensor): mean and log of variance of Q(z|X)

    # Returns
        z (tensor): sampled latent vector
    """
    #Extract mean and log of variance
    z_mean, z_log_var = args
    #get batch size and length of vector (size of latent space)
    batch = K.shape(z_mean)[0]
    dim = K.int_shape(z_mean)[1]
    
    # by default, random_normal has mean = 0 and std = 1.0
    epsilon = K.random_normal(shape=(batch, dim))
    #Return sampled number (need to raise var to correct power)
    return z_mean + K.exp(z_log_var) * epsilon

# %%
encoder_inputs = keras.Input(shape=(32,32,1))
first_filter_count = 40
encoder_main = layers.Conv2D(filters=first_filter_count, kernel_size=(4,4), activation='relu', strides=1, padding='same')(encoder_inputs)
encoder_main = layers.MaxPooling2D(pool_size=2, strides=2, padding='valid')(encoder_main)
last_filter_count = 20
encoder_main = layers.Conv2D(filters=last_filter_count, kernel_size=(3,3), activation='relu', strides=1, padding='valid')(encoder_main)
encoder_main = layers.Flatten()(encoder_main)
encoder_main = layers.Dense(intermediate_dim, activation='relu')(encoder_main)

encoder_mean = layers.Dense(latent_dim, name="encoder_mean")(encoder_main)
encoder_log_var = layers.Dense(latent_dim, name="encoder_log_var")(encoder_main)
encoder_sampling = keras.layers.Lambda(sampling, name="encoder_output")([encoder_mean, encoder_log_var])

encoder = keras.Model(encoder_inputs, [encoder_mean, encoder_log_var, encoder_sampling], name="encoder")
encoder.summary()
opt = keras.optimizers.SGD(learning_rate=0.01)
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 32, 32, 1)]  0           []
#
#  conv2d (Conv2D)                (None, 32, 32, 40)   680         ['input_1[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 16, 16, 40)   0           ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 14, 14, 20)   7220        ['max_pooling2d[0][0]']
#
#  flatten (Flatten)              (None, 3920)         0           ['conv2d_1[0][0]']
#
#  dense (Dense)                  (None, 512)          2007552     ['flatten[0][0]']
#
#  encoder_mean (Dense)           (None, 8)            4104        ['dense[0][0]']
#
#  encoder_log_var (Dense)        (None, 8)            4104        ['dense[0][0]']
#
#  encoder_output (Lambda)        (None, 8)            0           ['encoder_mean[0][0]',
#                                                                   'encoder_log_var[0][0]']
#
# ==================================================================================================
# Total params: 2,023,660
# Trainable params: 2,023,660
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
latent_inputs = keras.Input(shape=(latent_dim,))
decoder_main = layers.Dense(intermediate_dim, activation='relu')(latent_inputs)
decoder_main = layers.Dense(14*14*last_filter_count, activation='sigmoid')(decoder_main)
decoder_main = layers.Reshape((14,14,last_filter_count))(decoder_main)
decoder_main = layers.Conv2DTranspose(filters=last_filter_count, kernel_size=(4,4), activation="relu", strides=2, padding="valid")(decoder_main)
decoder_main = layers.Conv2DTranspose(filters=first_filter_count, kernel_size=(3,3), activation="relu", strides=1, padding="same")(decoder_main)
decoder_main = layers.Conv2DTranspose(filters=1, kernel_size=(3,3), activation="relu", strides=1, padding="valid")(decoder_main)
# instantiate decoder model
decoder = keras.Model(latent_inputs, decoder_main, name='decoder')
decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 8)]               0
#
#  dense_1 (Dense)             (None, 512)               4608
#
#  dense_2 (Dense)             (None, 3920)              2010960
#
#  reshape (Reshape)           (None, 14, 14, 20)        0
#
#  conv2d_transpose (Conv2DTra  (None, 30, 30, 20)       6420
#  nspose)
#
#  conv2d_transpose_1 (Conv2DT  (None, 30, 30, 40)       7240
#  ranspose)
#
#  conv2d_transpose_2 (Conv2DT  (None, 32, 32, 1)        361
#  ranspose)
#
# =================================================================
# Total params: 2,029,589
# Trainable params: 2,029,589
# Non-trainable params: 0
# _________________________________________________________________

# %%
decoder_outputs = decoder(encoder(encoder_inputs)[2])

vae = keras.Model(encoder_inputs, decoder_outputs, name='vae')
#reconstruction_loss = mse(encoder_inputs, decoder_outputs)
reconstruction_loss = tf.reduce_mean(
    tf.reduce_sum(
        (encoder_inputs - decoder_outputs)**2,
        axis=(1,2)
    )
)
reconstruction_loss *=1
print(reconstruction_loss)
kl_loss = K.exp(encoder_log_var) + K.square(encoder_mean) - encoder_log_var - 1
kl_loss = K.sum(kl_loss, axis=-1)
kl_loss *= 0.0001
vae_loss = K.mean(reconstruction_loss + kl_loss)
print(kl_loss)
print(vae_loss)

vae.add_loss(vae_loss)
vae.compile(optimizer='adam')

logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S_Task5"))
tensorboard_callback = keras.callbacks.TensorBoard(logdir, histogram_freq=1)

vae.fit(training_images, epochs=100, batch_size=int(len(training_images/2)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 decoder_outputs = decoder(encoder(encoder_inputs)[2])
#       3 vae = keras.Model(encoder_inputs, decoder_outputs, name='vae')
#       4 #reconstruction_loss = mse(encoder_inputs, decoder_outputs)
#
# NameError: name 'decoder' is not defined

# %%
test_output_images = vae(testing_images[15:25])
test_output_images= [np.array(x*255, dtype=np.uint8)[:,:,0] for x in test_output_images]

for x in test_output_images:
   display(Image.fromarray(x,mode="L").resize((100,100)))

# %%
test_images = decoder(K.constant([np.random.rand(latent_dim) for x in range(10)]))
test_images= [np.array(x*255, dtype=np.uint8)[:,:,0] for x in test_images]

for x in test_images:
   display(Image.fromarray(x,mode="L").resize((100,100)))
